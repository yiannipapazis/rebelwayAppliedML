# %%
import jax.numpy as jnp
from jax import jit

# %%
def relu(x):
    return jnp.maximum(0, x)
def softmax(x):
    return jnp.exp(x) / jnp.sum(jnp.exp(x), axis = 0)
def cross_entropy(x, y):
    return -jnp.sum(y * jnp.log(x))

# %%
x = jnp.arange(6.0)
print(relu(x))
print(softmax(x))
print(cross_entropy(softmax(x),x))
# Out:
# [0. 1. 2. 3. 4. 5.]
# [0.00426978 0.01160646 0.03154963 0.08576079 0.233122   0.6336913 ]
# 26.8429

# %%
from jax import random

key = random.PRNGKey(0)
key, subkey = random.split(key)
print(subkey)
# Out:
# [ 928981903 3453687069]

# %%
x = random.normal(key, (1_000_000,))
# %timeit relu(x)
# Out:
# 523 μs ± 19.4 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
jitted_relu = jit(relu)
a = jitted_relu(x)
# %timeit relu(a)
# Out:
# 508 μs ± 10.3 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
def selu(x, alpha=1.67, lmbda=1.05):
    return lmbda * jnp.where(x > 0, x, alpha * jnp.exp(x) - alpha)

key = random.key(1000)
x = random.normal(key, (1_000_000,))
# %timeit selu(x).block_until_ready()
# Out:
# 2.95 ms ± 142 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
selu_jit = jit(selu)
_ = selu_jit(x)
# %timeit selu_jit(x).block_until_ready()
# Out:
# 574 μs ± 4.68 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
def mm(x, y):
    return jnp.dot(x, y)

@jit
def mm_jit(x, y):
    return jnp.dot(x, y)

# %%
a = random.normal(key, (1000, 1000))
b = random.normal(key, (1000, 1000))

# %%
# %timeit mm(a, b)

# %%
# %timeit mm_jit(a, b)
