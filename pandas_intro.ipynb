# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = pd.read_csv('user_behavior_dataset.csv')

# %%
data.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# 2                        32                  322   42    Male
# 3                        56                  871   20    Male
# 4                        58                  988   31  Female
#
#    User Behavior Class
# 0                    4
# 1                    3
# 2                    2
# 3                    3
# 4                    3

# %%
sns.heatmap(data.isnull(),yticklabels=False, cbar=False, cmap="viridis")
# Out:
# <Axes: >

# %%
data["Age"].value_counts()
# Out:
# Age
# 34    25
# 51    25
# 22    24
# 27    24
# 43    22
# 29    21
# 55    21
# 25    21
# 42    20
# 31    20
# 53    19
# 40    19
# 37    19
# 45    18
# 57    18
# 32    18
# 20    17
# 47    17
# 49    17
# 21    17
# 36    17
# 52    17
# 56    16
# 54    16
# 30    15
# 23    15
# 39    15
# 35    15
# 50    15
# 24    14
# 26    14
# 44    14
# 58    14
# 59    13
# 28    13
# 41    12
# 19    12
# 33    11
# 46    11
# 18    11
# 38     9
# 48     9
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Age",data=data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.scatterplot(data=data, x="Age", y="App Usage Time (min/day)")
# Out:
# <Axes: xlabel='Age', ylabel='App Usage Time (min/day)'>

# %%
data.describe()
# Out:
#          User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.00000                700.000000                  700.000000
# mean   350.50000                271.128571                    5.272714
# std    202.21688                177.199484                    3.068584
# min      1.00000                 30.000000                    1.000000
# 25%    175.75000                113.250000                    2.500000
# 50%    350.50000                227.500000                    4.900000
# 75%    525.25000                434.250000                    7.400000
# max    700.00000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               700.000000                700.000000           700.000000
# mean               1525.158571                 50.681429           929.742857
# std                 819.136414                 26.943324           640.451729
# min                 302.000000                 10.000000           102.000000
# 25%                 722.250000                 26.000000           373.000000
# 50%                1502.500000                 49.000000           823.500000
# 75%                2229.500000                 74.000000          1341.000000
# max                2993.000000                 99.000000          2497.000000
#
#               Age  User Behavior Class
# count  700.000000           700.000000
# mean    38.482857             2.990000
# std     12.012916             1.401476
# min     18.000000             1.000000
# 25%     28.000000             2.000000
# 50%     38.000000             3.000000
# 75%     49.000000             4.000000
# max     59.000000             5.000000

# %%
data.info
# Out:
# <bound method DataFrame.info of      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                           6.4                     1872
# 1                           4.7                     1331
# 2                           4.0                      761
# 3                           4.8                     1676
# 4                           4.3                     1367
# ..                          ...                      ...
# 695                         3.9                     1082
# 696                         6.8                     1965
# 697                         3.1                      942
# 698                         1.7                      431
# 699                         5.4                     1306
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                          67                 1122   40    Male
# 1                          42                  944   47  Female
# 2                          32                  322   42    Male
# 3                          56                  871   20    Male
# 4                          58                  988   31  Female
# ..                        ...                  ...  ...     ...
# 695                        26                  381   22    Male
# 696                        68                 1201   59    Male
# 697                        22                  457   50  Female
# 698                        13                  224   44    Male
# 699                        49                  828   23  Female
#
#      User Behavior Class
# 0                      4
# 1                      3
# 2                      2
# 3                      3
# 4                      3
# ..                   ...
# 695                    2
# 696                    4
# 697                    2
# 698                    1
# 699                    3
#
# [700 rows x 11 columns]>

# %%
data.columns
# Out:
# Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='object')

# %%
data.tail()
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 695                         3.9                     1082
# 696                         6.8                     1965
# 697                         3.1                      942
# 698                         1.7                      431
# 699                         5.4                     1306
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 695                        26                  381   22    Male
# 696                        68                 1201   59    Male
# 697                        22                  457   50  Female
# 698                        13                  224   44    Male
# 699                        49                  828   23  Female
#
#      User Behavior Class
# 695                    2
# 696                    4
# 697                    2
# 698                    1
# 699                    3

# %%
data.Age
# Out:
# 0      40
# 1      47
# 2      42
# 3      20
# 4      31
#        ..
# 695    22
# 696    59
# 697    50
# 698    44
# 699    23
# Name: Age, Length: 700, dtype: int64

# %%
data["Device Model"]
# Out:
# 0          Google Pixel 5
# 1               OnePlus 9
# 2            Xiaomi Mi 11
# 3          Google Pixel 5
# 4               iPhone 12
#               ...
# 695             iPhone 12
# 696          Xiaomi Mi 11
# 697        Google Pixel 5
# 698    Samsung Galaxy S21
# 699             OnePlus 9
# Name: Device Model, Length: 700, dtype: object

# %%
data = data.drop("User ID", axis=1)

# %%
data.head()
# Out:
#      Device Model Operating System  App Usage Time (min/day)  \
# 0  Google Pixel 5          Android                       393
# 1       OnePlus 9          Android                       268
# 2    Xiaomi Mi 11          Android                       154
# 3  Google Pixel 5          Android                       239
# 4       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# 2                        32                  322   42    Male
# 3                        56                  871   20    Male
# 4                        58                  988   31  Female
#
#    User Behavior Class
# 0                    4
# 1                    3
# 2                    2
# 3                    3
# 4                    3

# %%
data.loc[3]
# Out:
# Device Model                  Google Pixel 5
# Operating System                     Android
# App Usage Time (min/day)                 239
# Screen On Time (hours/day)               4.8
# Battery Drain (mAh/day)                 1676
# Number of Apps Installed                  56
# Data Usage (MB/day)                      871
# Age                                       20
# Gender                                  Male
# User Behavior Class                        3
# Name: 3, dtype: object

# %%
data.iloc[2]
# Out:
# Device Model                  Xiaomi Mi 11
# Operating System                   Android
# App Usage Time (min/day)               154
# Screen On Time (hours/day)             4.0
# Battery Drain (mAh/day)                761
# Number of Apps Installed                32
# Data Usage (MB/day)                    322
# Age                                     42
# Gender                                Male
# User Behavior Class                      2
# Name: 2, dtype: object

# %%
data.iloc[4:20]
# Out:
#           Device Model Operating System  App Usage Time (min/day)  \
# 4            iPhone 12              iOS                       187
# 5       Google Pixel 5          Android                        99
# 6   Samsung Galaxy S21          Android                       350
# 7            OnePlus 9          Android                       543
# 8   Samsung Galaxy S21          Android                       340
# 9            iPhone 12              iOS                       424
# 10      Google Pixel 5          Android                        53
# 11           OnePlus 9          Android                       215
# 12           OnePlus 9          Android                       462
# 13        Xiaomi Mi 11          Android                       215
# 14           iPhone 12              iOS                       189
# 15      Google Pixel 5          Android                       503
# 16           OnePlus 9          Android                       132
# 17           iPhone 12              iOS                       299
# 18      Google Pixel 5          Android                        81
# 19           iPhone 12              iOS                       577
#
#     Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 4                          4.3                     1367
# 5                          2.0                      940
# 6                          7.3                     1802
# 7                         11.4                     2956
# 8                          7.7                     2138
# 9                          6.6                     1957
# 10                         1.4                      435
# 11                         5.5                     1690
# 12                         6.2                     2303
# 13                         4.9                     1662
# 14                         5.4                     1754
# 15                        10.4                     2571
# 16                         3.6                      628
# 17                         5.8                     1431
# 18                         1.4                      558
# 19                         8.5                     2774
#
#     Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 4                         58                  988   31  Female
# 5                         35                  564   31    Male
# 6                         66                 1054   21  Female
# 7                         82                 1702   31    Male
# 8                         75                 1053   42  Female
# 9                         75                 1301   42    Male
# 10                        17                  162   34  Female
# 11                        47                  641   24    Male
# 12                        65                 1099   57  Female
# 13                        43                  857   43    Male
# 14                        53                  779   49  Female
# 15                        84                 2025   39  Female
# 16                        32                  344   47  Female
# 17                        41                  985   44  Female
# 18                        16                  297   26  Female
# 19                        89                 2192   29  Female
#
#     User Behavior Class
# 4                     3
# 5                     2
# 6                     4
# 7                     5
# 8                     4
# 9                     4
# 10                    1
# 11                    3
# 12                    4
# 13                    3
# 14                    3
# 15                    5
# 16                    2
# 17                    3
# 18                    1
# 19                    5

# %%
sns.lmplot(x="Age", y="App Usage Time (min/day)", data=data, hue="Gender", palette="muted")

# %%
sns.scatterplot(data=data, x="Device Model", y="Number of Apps Installed")
# Out:
# <Axes: xlabel='Device Model', ylabel='Number of Apps Installed'>

# %%
sns.jointplot(data=data, x="Age", y="Gender")

# %%
sns.pairplot(data, hue="Gender")

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.pivot_table(values="passengers", index="month", columns="year")
# Out:
# C:\Users\yiann\AppData\Local\Temp\ipykernel_26836\2915612774.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(values="passengers", index="month", columns="year")
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# Dec    118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0  337.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0
# Jun    472.0  535.0
# Jul    548.0  622.0
# Aug    559.0  606.0
# Sep    463.0  508.0
# Oct    407.0  461.0
# Nov    362.0  390.0
# Dec    405.0  432.0

# %%
sns.heatmap(flights.pivot_table(values="passengers", index="month", columns="year"))
# Out:
# C:\Users\yiann\AppData\Local\Temp\ipykernel_26836\1030848235.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values="passengers", index="month", columns="year"))
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values="passengers", index="month", columns="year"))
# Out:
# C:\Users\yiann\AppData\Local\Temp\ipykernel_26836\2966908717.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values="passengers", index="month", columns="year"))
